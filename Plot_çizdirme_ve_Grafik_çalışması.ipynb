# %% [markdown]
# <a href="https://colab.research.google.com/github/dragonfire-09/Homework-Global-AI-Hub/blob/main/Plot_%C3%A7izdirme_ve_Grafik_%C3%A7al%C4%B1%C5%9Fmas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #VERİ GÖRSELLEŞTİRME KOD ÇALIŞMASI

# %%
# !pip install matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1

# %% [markdown]
# # Install 7zip reader [libarchive](https://pypi.python.org/pypi/libarchive)

# %%
import matplotlip.pyplot  as plt

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive

# %% [markdown]
# # Install GraphViz & [PyDot](https://pypi.python.org/pypi/pydot)

# %%
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydot
import pydot

# %% [markdown]
# # Install [cartopy](http://scitools.org.uk/cartopy/docs/latest/)

# %%
# !pip install cartopy
import cartopy
# Out:
# ...
#      |████████████████████████████████| 12.1 MB 133 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 219 kB 52.8 MB/s
# ...
#   Created wheel for cartopy: filename=Cartopy-0.19.0.post1-cp37-cp37m-linux_x86_64.whl size=12516280 sha256=d2d31f4fa0aec25823cb13876a9e3b217cee6f42c12c2dad4393eeef78fcc5b0
#   Stored in directory: /root/.cache/pip/wheels/98/01/f7/bd10aeb96fe4b518cde5f7c4f5e12c7202f85b7353a5017847
# ...
#   Created wheel for pyshp: filename=pyshp-2.1.3-py3-none-any.whl size=37325 sha256=7435a52eb9eb700bd353c526925ef208bd0ed814b446be1a1f551249612c202c
#   Stored in directory: /root/.cache/pip/wheels/43/f8/87/53c8cd41545ba20e536ea29a8fcb5431b5f477ca50d5dffbbe
# Successfully built cartopy pyshp
# ...

# %%
# %matplotlib
# Out:
# Using matplotlib backend: agg

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0, 10,  100)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.xlabel('x ekseni')
plt.ylabel('y ekseni')

plt.legend(('sin', 'cos'))

# %%
fig=plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %%
import seaborn as sns
import pandas as pd

# %%
iris= sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
pip install -U statsmodels

# %%
iris['petal_length'].plot()

# %%
sns.lineplot(data=iris, y='petal_width', x= iris.index, hue='species')

# %%
from numpy.random import seed
from numpy.random import randn
from matplotlib import pyplot

x = 60 + randn (1000) + 100

y = x + (10 +randn(1000) +50)

pyplot.scatter (x, y)
pyplot.show()

# %%
fig, ax = plt.subplots()
ax.scatter(iris ['sepal_length'], iris ['sepal_width'])
ax.set_title('iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
import pandas
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = pandas.read_csv(url, names=names)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
tips= sns.load_dataset("tips")
tips.head()
tips.describe().T
sns.barplot(x= 'day' ,
            y= "total_bill" , 
             data = tips)

# %%
iris.groupby(by ='species').mean() ['sepal_length']
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
data=iris.groupby(by ='species').max()['sepal_length']
ax= sns.barplot(x= data.index ,y= data.values , )
ax.set_title ('sepal_length Means')
ax.set_ylabel('max')
# Out:
# Text(0, 0.5, 'max')

# %%
penguins= sns.load_dataset("penguins")
penguins.head()
penguins.describe().T
sns.histplot(data=penguins, x= "flipper_length_mm")

# %%
sns.histplot(data=iris , x= 'sepal_width', hue='species', bins=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fe0acb674fd9> in <module>()
# ----> 1 sns.histplot(data=iris , x= 'sepal_width', hue='species', bins=20)
#
# NameError: name 'sns' is not defined

# %%
sns.histplot(data=iris , x= 'sepal_width', hue='species', bins=10)

# %%
import matplotlib.pyplot as plt
import numpy as np
y= np.array([35,25,30,15,10])
labels= ["apples", "bananas" ,"cherries", "Dates","ananas"]

plt.pie(y,labels=labels)
plt.show()

# %%
import numpy as np
np.random.seed()
uniform_data= np.random.rand(10,12)
ax= sns.heatmap(uniform_data)

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr() , annot=True)

# %%
tips= sns.load_dataset("tips")
tips.head()
tips.describe().T
sns.boxplot(x= tips["total_bill"])

# %%
sns.boxplot(data=iris , y= 'sepal_length', x= 'species')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
